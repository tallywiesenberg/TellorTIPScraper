# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm

# %%
df = pd.read_csv('../votes.csv')
df['Vote'] = df['Vote'].replace({True: 'For', False: 'Against'})
df.head()
# Out:
#                                       Address    Balance Vote
# 0  0x67d18c47A96F62c1ce7d743a95c178789d0dbe91   5.286076  For
# 1  0xCA2c1EE8C0274C6719d36E0576b3e94eA9a5c383   8.141587  For
# 2  0xDb0C980a0a9EdD23511C330FAf6BE21D9b478550  15.150460  For
# 3  0xB2D6AAF0bca136C252Ec94F0f06c2489F734675f  20.237424  For
# 4  0xA63e7ea07aBA5E89Aa530a206230f3007f90AA10  21.320906  For

# %%
tellor_colors = ['#08F788', '#414141']
pallete = sns.color_palette(palette=tellor_colors, n_colors=2, desat=True)
sns.set_palette(pallete)

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\tally\\Repositories\\Tellor\\TellorTIPScraper\\notebooks'

# %%
fig, ax = plt.subplots(figsize=(16, 9), frameon=False)

font_path = os.path.join("../extras", "Renogare.ttf")
font_main = fm.FontProperties(fname=font_path, size=64)
font_path = os.path.join("../extras", "Roboto-Medium.ttf")
font_body = fm.FontProperties(fname=font_path, size=24)
fname = os.path.split(font_path)[1]
ax = sns.barplot(data=df, x='Address', y='Balance', hue='Vote')
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Address', fontproperties=font_body, fontsize=16, labelpad=10)
ax.set_ylabel('Balance (TRB)', fontproperties=font_body, fontsize=16)
ax.legend(title='Voted...', loc='center left', fontsize=20, title_fontsize=24, frameon=False, prop=font_body).set_title(title='Voted...', prop=font_body)
ax.set_yscale("log")

ax.set_title('V2.5 Voter Balances', fontproperties=font_main)
# ax.title.set_fontsize(48)
for panel in ['top', 'bottom', 'left', 'right']:
    ax.spines[panel].set_visible(False)

# %%
fig.savefig(os.path.join("..\\extras", "votes_graph.png"), dpi=75)

# %% [markdown]
# ax.set_title('This is a special font: {}'.format(fname), fontproperties=prop)
